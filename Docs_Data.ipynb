# %%
import requests
from bs4 import BeautifulSoup
import os
import re

HEADERS = {"User-Agent": "Mozilla/5.0"}

DOCUMENTATION_SOURCES = {

    # ======================================
    # FASTAPI
    # ======================================
    "fastapi": {
        "framework": "FastAPI",
        "selector": ".md-content",
        "urls": [
            # Installation & setup
            "https://fastapi.tiangolo.com/installation/",
            "https://fastapi.tiangolo.com/python-types/",
            "https://fastapi.tiangolo.com/async/",
            "https://fastapi.tiangolo.com/virtual-environments/",
            "https://fastapi.tiangolo.com/fastapi-cli/",
            "https://fastapi.tiangolo.com/deployment/server-workers/",
            "https://fastapi.tiangolo.com/deployment/docker/",

            # Basics
            "https://fastapi.tiangolo.com/tutorial/first-steps/",
            "https://fastapi.tiangolo.com/tutorial/path-params/",
            "https://fastapi.tiangolo.com/tutorial/query-params/",
            "https://fastapi.tiangolo.com/tutorial/body/",
            "https://fastapi.tiangolo.com/tutorial/body-fields/",
            "https://fastapi.tiangolo.com/tutorial/body-nested-models/",
            "https://fastapi.tiangolo.com/tutorial/cookie-params/",
            "https://fastapi.tiangolo.com/tutorial/header-params/",
            "https://fastapi.tiangolo.com/tutorial/request-forms/",
            "https://fastapi.tiangolo.com/tutorial/request-files/",
            "https://fastapi.tiangolo.com/tutorial/response-model/",
            "https://fastapi.tiangolo.com/tutorial/response-status-code/",
            "https://fastapi.tiangolo.com/tutorial/handling-errors/",

            # Intermediate
            "https://fastapi.tiangolo.com/tutorial/dependencies/",
            "https://fastapi.tiangolo.com/tutorial/dependencies/classes-as-dependencies/",
            "https://fastapi.tiangolo.com/tutorial/dependencies/sub-dependencies/",
            "https://fastapi.tiangolo.com/tutorial/security/",
            "https://fastapi.tiangolo.com/tutorial/security/oauth2-jwt/",
            "https://fastapi.tiangolo.com/tutorial/middleware/",
            "https://fastapi.tiangolo.com/tutorial/cors/",
            "https://fastapi.tiangolo.com/tutorial/sql-databases/",
            "https://fastapi.tiangolo.com/tutorial/background-tasks/",
            "https://fastapi.tiangolo.com/tutorial/static-files/",
            "https://fastapi.tiangolo.com/tutorial/testing/",
            "https://fastapi.tiangolo.com/tutorial/debugging/",

            # Advanced
            "https://fastapi.tiangolo.com/advanced/additional-status-codes/",
            "https://fastapi.tiangolo.com/advanced/response-directly/",
            "https://fastapi.tiangolo.com/advanced/custom-response/",
            "https://fastapi.tiangolo.com/advanced/response-cookies/",
            "https://fastapi.tiangolo.com/advanced/response-headers/",
            "https://fastapi.tiangolo.com/advanced/websockets/",
            "https://fastapi.tiangolo.com/advanced/events/",
            "https://fastapi.tiangolo.com/advanced/sub-applications/",
            "https://fastapi.tiangolo.com/advanced/middleware/",
        ],
    },

    # ======================================
    # REACT
    # ======================================
    "react": {
        "framework": "React",
        "selector": "main, article",
        "urls": [
            "https://react.dev/learn",
            "https://react.dev/learn/thinking-in-react",
            "https://react.dev/learn/describing-the-ui",
            "https://react.dev/learn/adding-interactivity",
            "https://react.dev/learn/managing-state",

            # Hooks
            "https://react.dev/reference/react/useState",
            "https://react.dev/reference/react/useEffect",
            "https://react.dev/reference/react/useContext",
            "https://react.dev/reference/react/useReducer",
            "https://react.dev/reference/react/useRef",
            "https://react.dev/reference/react/useMemo",
            "https://react.dev/reference/react/useCallback",

            # Advanced
            "https://react.dev/learn/escape-hatches",
            "https://react.dev/learn/you-might-not-need-an-effect",
            "https://react.dev/reference/react/Component",
        ],
    },

    # ======================================
    # NEXT.JS
    # ======================================
    "nextjs": {
        "framework": "Next.js",
        "selector": "main, article",
        "urls": [
            "https://nextjs.org/docs/app/building-your-application/routing",
            "https://nextjs.org/docs/app/building-your-application/routing/defining-routes",
            "https://nextjs.org/docs/app/building-your-application/routing/pages-and-layouts",
            "https://nextjs.org/docs/app/building-your-application/routing/dynamic-routes",
            "https://nextjs.org/docs/app/building-your-application/routing/loading-ui-and-streaming",

            # Data
            "https://nextjs.org/docs/app/building-your-application/data-fetching",
            "https://nextjs.org/docs/app/building-your-application/data-fetching/server-actions-and-mutations",
            "https://nextjs.org/docs/app/building-your-application/caching",

            # API
            "https://nextjs.org/docs/app/building-your-application/routing/route-handlers",
            "https://nextjs.org/docs/app/api-reference/functions/server-actions",

            # Components
            "https://nextjs.org/docs/app/api-reference/components/image",
            "https://nextjs.org/docs/app/api-reference/components/link",
            "https://nextjs.org/docs/app/building-your-application/optimizing",

            # Deployment
            "https://nextjs.org/docs/app/building-your-application/deploying",
        ],
    },

    # ======================================
    # EXPRESS
    # ======================================
    "express": {
        "framework": "Express.js",
        "selector": "#page-doc",
        "urls": [
            "https://expressjs.com/en/starter/hello-world.html",
            "https://expressjs.com/en/starter/basic-routing.html",
            "https://expressjs.com/en/guide/routing.html",
            "https://expressjs.com/en/guide/using-middleware.html",
            "https://expressjs.com/en/guide/writing-middleware.html",
            "https://expressjs.com/en/guide/error-handling.html",
            "https://expressjs.com/en/guide/database-integration.html",
            "https://expressjs.com/en/advanced/best-practice-security.html",
            "https://expressjs.com/en/advanced/best-practice-performance.html",
        ],
    },

    # ======================================
    # POSTGRESQL
    # ======================================
    "postgresql": {
        "framework": "PostgreSQL",
        "selector": ".SECT1, .SECT2",
        "urls": [
            "https://www.postgresql.org/docs/current/tutorial-select.html",
            "https://www.postgresql.org/docs/current/tutorial-join.html",
            "https://www.postgresql.org/docs/current/tutorial-agg.html",
            "https://www.postgresql.org/docs/current/tutorial-views.html",
            "https://www.postgresql.org/docs/current/tutorial-transactions.html",
            "https://www.postgresql.org/docs/current/ddl.html",
            "https://www.postgresql.org/docs/current/indexes.html",
        ],
    },

    # ======================================
    # MONGODB
    # ======================================
    "mongodb": {
        "framework": "MongoDB",
        "selector": ".body",
        "urls": [
            "https://www.mongodb.com/docs/manual/tutorial/getting-started/",
            "https://www.mongodb.com/docs/manual/tutorial/insert-documents/",
            "https://www.mongodb.com/docs/manual/tutorial/query-documents/",
            "https://www.mongodb.com/docs/manual/tutorial/update-documents/",
            "https://www.mongodb.com/docs/manual/tutorial/remove-documents/",
            "https://www.mongodb.com/docs/manual/aggregation/",
            "https://www.mongodb.com/docs/manual/indexes/",
        ],
    },

    # ======================================
    # DOCKER
    # ======================================
    "docker": {
        "framework": "Docker",
        "selector": "article",
        "urls": [
            "https://docs.docker.com/get-started/",
            "https://docs.docker.com/get-started/02_our_app/",
            "https://docs.docker.com/get-started/03_updating_app/",
            "https://docs.docker.com/get-started/04_sharing_app/",
            "https://docs.docker.com/get-started/05_persisting_data/",
            "https://docs.docker.com/get-started/06_bind_mounts/",
            "https://docs.docker.com/get-started/07_multi_container/",
            "https://docs.docker.com/compose/gettingstarted/",
        ],
    },

    # ======================================
    # AWS
    # ======================================
    "aws": {
        "framework": "AWS",
        "selector": ".awsui-util-container",
        "urls": [
            # S3
            "https://docs.aws.amazon.com/AmazonS3/latest/userguide/creating-bucket.html",
            "https://docs.aws.amazon.com/AmazonS3/latest/userguide/upload-objects.html",

            # Lambda
            "https://docs.aws.amazon.com/lambda/latest/dg/getting-started.html",
            "https://docs.aws.amazon.com/lambda/latest/dg/python-handler.html",

            # EC2
            "https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/EC2_GetStarted.html",
            "https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/launching-instance.html",

            # DynamoDB
            "https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStartedDynamoDB.html",
        ],
    },

    # ======================================
    # PANDAS
    # ======================================
    "pandas": {
        "framework": "Pandas",
        "selector": ".body",
        "urls": [
            "https://pandas.pydata.org/docs/user_guide/10min.html",
            "https://pandas.pydata.org/docs/user_guide/dsintro.html",
            "https://pandas.pydata.org/docs/user_guide/indexing.html",
            "https://pandas.pydata.org/docs/user_guide/merging.html",
            "https://pandas.pydata.org/docs/user_guide/groupby.html",
            "https://pandas.pydata.org/docs/user_guide/reshaping.html",
            "https://pandas.pydata.org/docs/user_guide/io.html",
        ],
    },

    # ======================================
    # NUMPY
    # ======================================
    "numpy": {
        "framework": "NumPy",
        "selector": "article",
        "urls": [
            "https://numpy.org/doc/stable/user/quickstart.html",
            "https://numpy.org/doc/stable/user/basics.creation.html",
            "https://numpy.org/doc/stable/user/basics.indexing.html",
            "https://numpy.org/doc/stable/user/basics.broadcasting.html",
            "https://numpy.org/doc/stable/reference/routines.array-manipulation.html",
        ],
    },

    # ======================================
    # TYPESCRIPT
    # ======================================
    "typescript": {
        "framework": "TypeScript",
        "selector": "article",
        "urls": [
            "https://www.typescriptlang.org/docs/handbook/2/basic-types.html",
            "https://www.typescriptlang.org/docs/handbook/2/everyday-types.html",
            "https://www.typescriptlang.org/docs/handbook/2/narrowing.html",
            "https://www.typescriptlang.org/docs/handbook/2/functions.html",
            "https://www.typescriptlang.org/docs/handbook/2/objects.html",
            "https://www.typescriptlang.org/docs/handbook/2/classes.html",
            "https://www.typescriptlang.org/docs/handbook/2/generics.html",
        ],
    },

    # ======================================
    # TAILWIND
    # ======================================
    "tailwind": {
        "framework": "Tailwind CSS",
        "selector": "#content-wrapper",
        "urls": [
            "https://tailwindcss.com/docs/utility-first",
            "https://tailwindcss.com/docs/responsive-design",
            "https://tailwindcss.com/docs/hover-focus-and-other-states",
            "https://tailwindcss.com/docs/dark-mode",
            "https://tailwindcss.com/docs/adding-custom-styles",
            "https://tailwindcss.com/docs/installation",
        ],
    },

    # ======================================
    # PRISMA
    # ======================================
    "prisma": {
        "framework": "Prisma ORM",
        "selector": "article",
        "urls": [
            "https://www.prisma.io/docs/getting-started/quickstart",
            "https://www.prisma.io/docs/concepts/components/prisma-schema",
            "https://www.prisma.io/docs/concepts/components/prisma-client",
            "https://www.prisma.io/docs/concepts/components/prisma-client/crud",
            "https://www.prisma.io/docs/concepts/components/prisma-client/relation-queries",
            "https://www.prisma.io/docs/guides/performance-and-optimization",
        ],
    },

    # ======================================
    # REDIS
    # ======================================
    "redis": {
        "framework": "Redis",
        "selector": ".prose",
        "urls": [
            "https://redis.io/docs/getting-started/",
            "https://redis.io/docs/data-types/strings/",
            "https://redis.io/docs/data-types/lists/",
            "https://redis.io/docs/data-types/sets/",
            "https://redis.io/docs/data-types/hashes/",
            "https://redis.io/docs/manual/patterns/",
        ],
    },
}


BASE_DIR = "docs_dataset"
os.makedirs(BASE_DIR, exist_ok=True)

def slugify(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9]+", "-", text)
    return text.strip("-")

for key, cfg in DOCUMENTATION_SOURCES.items():
    framework = cfg["framework"]
    selector = cfg["selector"]
    urls = cfg["urls"]

    print(f"\n📘 Processing framework: {framework}")

    # folder per framework
    folder = os.path.join(BASE_DIR, slugify(framework))
    os.makedirs(folder, exist_ok=True)

    for url in urls:
        print(f" → Fetching {url}")

        res = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(res.text, "html.parser")

        # page title
        h1 = soup.find("h1")
        title = h1.get_text(strip=True) if h1 else url

        # extract main content using selector
        content = soup.select_one(selector)

        if content:
            text = content.get_text(separator="\n", strip=True)
        else:
            text = soup.get_text(separator="\n", strip=True)

        # filename from URL segment
        slug = slugify(url.rstrip("/").split("/")[-1] or "index")
        filepath = os.path.join(folder, f"{slug}.txt")

        with open(filepath, "w", encoding="utf-8") as f:
            f.write(title + "\n\n" + text)

        print(f"   ✔ Saved → {filepath}")
# Out:
# 📘 Processing framework: FastAPI
#  → Fetching https://fastapi.tiangolo.com/installation/
#    ✔ Saved → docs_dataset/fastapi/installation.txt
#  → Fetching https://fastapi.tiangolo.com/python-types/
#    ✔ Saved → docs_dataset/fastapi/python-types.txt
#  → Fetching https://fastapi.tiangolo.com/async/
#    ✔ Saved → docs_dataset/fastapi/async.txt
#  → Fetching https://fastapi.tiangolo.com/virtual-environments/
#    ✔ Saved → docs_dataset/fastapi/virtual-environments.txt
#  → Fetching https://fastapi.tiangolo.com/fastapi-cli/
#    ✔ Saved → docs_dataset/fastapi/fastapi-cli.txt
#  → Fetching https://fastapi.tiangolo.com/deployment/server-workers/
#    ✔ Saved → docs_dataset/fastapi/server-workers.txt
#  → Fetching https://fastapi.tiangolo.com/deployment/docker/
#    ✔ Saved → docs_dataset/fastapi/docker.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/first-steps/
#    ✔ Saved → docs_dataset/fastapi/first-steps.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/path-params/
#    ✔ Saved → docs_dataset/fastapi/path-params.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/query-params/
#    ✔ Saved → docs_dataset/fastapi/query-params.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/body/
#    ✔ Saved → docs_dataset/fastapi/body.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/body-fields/
#    ✔ Saved → docs_dataset/fastapi/body-fields.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/body-nested-models/
#    ✔ Saved → docs_dataset/fastapi/body-nested-models.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/cookie-params/
#    ✔ Saved → docs_dataset/fastapi/cookie-params.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/header-params/
#    ✔ Saved → docs_dataset/fastapi/header-params.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/request-forms/
#    ✔ Saved → docs_dataset/fastapi/request-forms.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/request-files/
#    ✔ Saved → docs_dataset/fastapi/request-files.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/response-model/
#    ✔ Saved → docs_dataset/fastapi/response-model.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/response-status-code/
#    ✔ Saved → docs_dataset/fastapi/response-status-code.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/handling-errors/
#    ✔ Saved → docs_dataset/fastapi/handling-errors.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/dependencies/
#    ✔ Saved → docs_dataset/fastapi/dependencies.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/dependencies/classes-as-dependencies/
#    ✔ Saved → docs_dataset/fastapi/classes-as-dependencies.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/dependencies/sub-dependencies/
#    ✔ Saved → docs_dataset/fastapi/sub-dependencies.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/security/
#    ✔ Saved → docs_dataset/fastapi/security.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/security/oauth2-jwt/
#    ✔ Saved → docs_dataset/fastapi/oauth2-jwt.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/middleware/
#    ✔ Saved → docs_dataset/fastapi/middleware.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/cors/
#    ✔ Saved → docs_dataset/fastapi/cors.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/sql-databases/
#    ✔ Saved → docs_dataset/fastapi/sql-databases.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/background-tasks/
#    ✔ Saved → docs_dataset/fastapi/background-tasks.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/static-files/
#    ✔ Saved → docs_dataset/fastapi/static-files.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/testing/
#    ✔ Saved → docs_dataset/fastapi/testing.txt
#  → Fetching https://fastapi.tiangolo.com/tutorial/debugging/
#    ✔ Saved → docs_dataset/fastapi/debugging.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/additional-status-codes/
#    ✔ Saved → docs_dataset/fastapi/additional-status-codes.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/response-directly/
#    ✔ Saved → docs_dataset/fastapi/response-directly.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/custom-response/
#    ✔ Saved → docs_dataset/fastapi/custom-response.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/response-cookies/
#    ✔ Saved → docs_dataset/fastapi/response-cookies.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/response-headers/
#    ✔ Saved → docs_dataset/fastapi/response-headers.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/websockets/
#    ✔ Saved → docs_dataset/fastapi/websockets.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/events/
#    ✔ Saved → docs_dataset/fastapi/events.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/sub-applications/
#    ✔ Saved → docs_dataset/fastapi/sub-applications.txt
#  → Fetching https://fastapi.tiangolo.com/advanced/middleware/
#    ✔ Saved → docs_dataset/fastapi/middleware.txt
#
# 📘 Processing framework: React
#  → Fetching https://react.dev/learn
#    ✔ Saved → docs_dataset/react/learn.txt
#  → Fetching https://react.dev/learn/thinking-in-react
#    ✔ Saved → docs_dataset/react/thinking-in-react.txt
#  → Fetching https://react.dev/learn/describing-the-ui
#    ✔ Saved → docs_dataset/react/describing-the-ui.txt
#  → Fetching https://react.dev/learn/adding-interactivity
#    ✔ Saved → docs_dataset/react/adding-interactivity.txt
#  → Fetching https://react.dev/learn/managing-state
#    ✔ Saved → docs_dataset/react/managing-state.txt
#  → Fetching https://react.dev/reference/react/useState
#    ✔ Saved → docs_dataset/react/usestate.txt
#  → Fetching https://react.dev/reference/react/useEffect
#    ✔ Saved → docs_dataset/react/useeffect.txt
#  → Fetching https://react.dev/reference/react/useContext
#    ✔ Saved → docs_dataset/react/usecontext.txt
#  → Fetching https://react.dev/reference/react/useReducer
#    ✔ Saved → docs_dataset/react/usereducer.txt
#  → Fetching https://react.dev/reference/react/useRef
#    ✔ Saved → docs_dataset/react/useref.txt
#  → Fetching https://react.dev/reference/react/useMemo
#    ✔ Saved → docs_dataset/react/usememo.txt
#  → Fetching https://react.dev/reference/react/useCallback
#    ✔ Saved → docs_dataset/react/usecallback.txt
#  → Fetching https://react.dev/learn/escape-hatches
#    ✔ Saved → docs_dataset/react/escape-hatches.txt
#  → Fetching https://react.dev/learn/you-might-not-need-an-effect
#    ✔ Saved → docs_dataset/react/you-might-not-need-an-effect.txt
#  → Fetching https://react.dev/reference/react/Component
#    ✔ Saved → docs_dataset/react/component.txt
#
# 📘 Processing framework: Next.js
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing
#    ✔ Saved → docs_dataset/next-js/routing.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing/defining-routes
#    ✔ Saved → docs_dataset/next-js/defining-routes.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing/pages-and-layouts
#    ✔ Saved → docs_dataset/next-js/pages-and-layouts.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing/dynamic-routes
#    ✔ Saved → docs_dataset/next-js/dynamic-routes.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing/loading-ui-and-streaming
#    ✔ Saved → docs_dataset/next-js/loading-ui-and-streaming.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/data-fetching
#    ✔ Saved → docs_dataset/next-js/data-fetching.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/data-fetching/server-actions-and-mutations
#    ✔ Saved → docs_dataset/next-js/server-actions-and-mutations.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/caching
#    ✔ Saved → docs_dataset/next-js/caching.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/routing/route-handlers
#    ✔ Saved → docs_dataset/next-js/route-handlers.txt
#  → Fetching https://nextjs.org/docs/app/api-reference/functions/server-actions
#    ✔ Saved → docs_dataset/next-js/server-actions.txt
#  → Fetching https://nextjs.org/docs/app/api-reference/components/image
#    ✔ Saved → docs_dataset/next-js/image.txt
#  → Fetching https://nextjs.org/docs/app/api-reference/components/link
#    ✔ Saved → docs_dataset/next-js/link.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/optimizing
#    ✔ Saved → docs_dataset/next-js/optimizing.txt
#  → Fetching https://nextjs.org/docs/app/building-your-application/deploying
#    ✔ Saved → docs_dataset/next-js/deploying.txt
#
# 📘 Processing framework: Express.js
#  → Fetching https://expressjs.com/en/starter/hello-world.html
#    ✔ Saved → docs_dataset/express-js/hello-world-html.txt
#  → Fetching https://expressjs.com/en/starter/basic-routing.html
#    ✔ Saved → docs_dataset/express-js/basic-routing-html.txt
#  → Fetching https://expressjs.com/en/guide/routing.html
#    ✔ Saved → docs_dataset/express-js/routing-html.txt
#  → Fetching https://expressjs.com/en/guide/using-middleware.html
#    ✔ Saved → docs_dataset/express-js/using-middleware-html.txt
#  → Fetching https://expressjs.com/en/guide/writing-middleware.html
#    ✔ Saved → docs_dataset/express-js/writing-middleware-html.txt
#  → Fetching https://expressjs.com/en/guide/error-handling.html
#    ✔ Saved → docs_dataset/express-js/error-handling-html.txt
#  → Fetching https://expressjs.com/en/guide/database-integration.html
#    ✔ Saved → docs_dataset/express-js/database-integration-html.txt
#  → Fetching https://expressjs.com/en/advanced/best-practice-security.html
#    ✔ Saved → docs_dataset/express-js/best-practice-security-html.txt
#  → Fetching https://expressjs.com/en/advanced/best-practice-performance.html
#    ✔ Saved → docs_dataset/express-js/best-practice-performance-html.txt
#
# 📘 Processing framework: PostgreSQL
#  → Fetching https://www.postgresql.org/docs/current/tutorial-select.html
#    ✔ Saved → docs_dataset/postgresql/tutorial-select-html.txt
#  → Fetching https://www.postgresql.org/docs/current/tutorial-join.html
#    ✔ Saved → docs_dataset/postgresql/tutorial-join-html.txt
#  → Fetching https://www.postgresql.org/docs/current/tutorial-agg.html
#    ✔ Saved → docs_dataset/postgresql/tutorial-agg-html.txt
#  → Fetching https://www.postgresql.org/docs/current/tutorial-views.html
#    ✔ Saved → docs_dataset/postgresql/tutorial-views-html.txt
#  → Fetching https://www.postgresql.org/docs/current/tutorial-transactions.html
#    ✔ Saved → docs_dataset/postgresql/tutorial-transactions-html.txt
#  → Fetching https://www.postgresql.org/docs/current/ddl.html
#    ✔ Saved → docs_dataset/postgresql/ddl-html.txt
#  → Fetching https://www.postgresql.org/docs/current/indexes.html
#    ✔ Saved → docs_dataset/postgresql/indexes-html.txt
#
# 📘 Processing framework: MongoDB
#  → Fetching https://www.mongodb.com/docs/manual/tutorial/getting-started/
#    ✔ Saved → docs_dataset/mongodb/getting-started.txt
#  → Fetching https://www.mongodb.com/docs/manual/tutorial/insert-documents/
#    ✔ Saved → docs_dataset/mongodb/insert-documents.txt
#  → Fetching https://www.mongodb.com/docs/manual/tutorial/query-documents/
#    ✔ Saved → docs_dataset/mongodb/query-documents.txt
#  → Fetching https://www.mongodb.com/docs/manual/tutorial/update-documents/
#    ✔ Saved → docs_dataset/mongodb/update-documents.txt
#  → Fetching https://www.mongodb.com/docs/manual/tutorial/remove-documents/
#    ✔ Saved → docs_dataset/mongodb/remove-documents.txt
#  → Fetching https://www.mongodb.com/docs/manual/aggregation/
#    ✔ Saved → docs_dataset/mongodb/aggregation.txt
#  → Fetching https://www.mongodb.com/docs/manual/indexes/
#    ✔ Saved → docs_dataset/mongodb/indexes.txt
#
# 📘 Processing framework: Docker
#  → Fetching https://docs.docker.com/get-started/
#    ✔ Saved → docs_dataset/docker/get-started.txt
#  → Fetching https://docs.docker.com/get-started/02_our_app/
#    ✔ Saved → docs_dataset/docker/02-our-app.txt
#  → Fetching https://docs.docker.com/get-started/03_updating_app/
#    ✔ Saved → docs_dataset/docker/03-updating-app.txt
#  → Fetching https://docs.docker.com/get-started/04_sharing_app/
#    ✔ Saved → docs_dataset/docker/04-sharing-app.txt
#  → Fetching https://docs.docker.com/get-started/05_persisting_data/
#    ✔ Saved → docs_dataset/docker/05-persisting-data.txt
#  → Fetching https://docs.docker.com/get-started/06_bind_mounts/
#    ✔ Saved → docs_dataset/docker/06-bind-mounts.txt
#  → Fetching https://docs.docker.com/get-started/07_multi_container/
#    ✔ Saved → docs_dataset/docker/07-multi-container.txt
#  → Fetching https://docs.docker.com/compose/gettingstarted/
#    ✔ Saved → docs_dataset/docker/gettingstarted.txt
#
# 📘 Processing framework: AWS
#  → Fetching https://docs.aws.amazon.com/AmazonS3/latest/userguide/creating-bucket.html
#    ✔ Saved → docs_dataset/aws/creating-bucket-html.txt
#  → Fetching https://docs.aws.amazon.com/AmazonS3/latest/userguide/upload-objects.html
#    ✔ Saved → docs_dataset/aws/upload-objects-html.txt
#  → Fetching https://docs.aws.amazon.com/lambda/latest/dg/getting-started.html
#    ✔ Saved → docs_dataset/aws/getting-started-html.txt
#  → Fetching https://docs.aws.amazon.com/lambda/latest/dg/python-handler.html
#    ✔ Saved → docs_dataset/aws/python-handler-html.txt
#  → Fetching https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/EC2_GetStarted.html
#    ✔ Saved → docs_dataset/aws/ec2-getstarted-html.txt
#  → Fetching https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/launching-instance.html
#    ✔ Saved → docs_dataset/aws/launching-instance-html.txt
#  → Fetching https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/GettingStartedDynamoDB.html
#    ✔ Saved → docs_dataset/aws/gettingstarteddynamodb-html.txt
#
# 📘 Processing framework: Pandas
#  → Fetching https://pandas.pydata.org/docs/user_guide/10min.html
#    ✔ Saved → docs_dataset/pandas/10min-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/dsintro.html
#    ✔ Saved → docs_dataset/pandas/dsintro-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/indexing.html
#    ✔ Saved → docs_dataset/pandas/indexing-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/merging.html
#    ✔ Saved → docs_dataset/pandas/merging-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/groupby.html
#    ✔ Saved → docs_dataset/pandas/groupby-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/reshaping.html
#    ✔ Saved → docs_dataset/pandas/reshaping-html.txt
#  → Fetching https://pandas.pydata.org/docs/user_guide/io.html
#    ✔ Saved → docs_dataset/pandas/io-html.txt
#
# 📘 Processing framework: NumPy
#  → Fetching https://numpy.org/doc/stable/user/quickstart.html
#    ✔ Saved → docs_dataset/numpy/quickstart-html.txt
#  → Fetching https://numpy.org/doc/stable/user/basics.creation.html
#    ✔ Saved → docs_dataset/numpy/basics-creation-html.txt
#  → Fetching https://numpy.org/doc/stable/user/basics.indexing.html
#    ✔ Saved → docs_dataset/numpy/basics-indexing-html.txt
#  → Fetching https://numpy.org/doc/stable/user/basics.broadcasting.html
#    ✔ Saved → docs_dataset/numpy/basics-broadcasting-html.txt
#  → Fetching https://numpy.org/doc/stable/reference/routines.array-manipulation.html
#    ✔ Saved → docs_dataset/numpy/routines-array-manipulation-html.txt
#
# 📘 Processing framework: TypeScript
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/basic-types.html
#    ✔ Saved → docs_dataset/typescript/basic-types-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/everyday-types.html
#    ✔ Saved → docs_dataset/typescript/everyday-types-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/narrowing.html
#    ✔ Saved → docs_dataset/typescript/narrowing-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/functions.html
#    ✔ Saved → docs_dataset/typescript/functions-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/objects.html
#    ✔ Saved → docs_dataset/typescript/objects-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/classes.html
#    ✔ Saved → docs_dataset/typescript/classes-html.txt
#  → Fetching https://www.typescriptlang.org/docs/handbook/2/generics.html
#    ✔ Saved → docs_dataset/typescript/generics-html.txt
#
# 📘 Processing framework: Tailwind CSS
#  → Fetching https://tailwindcss.com/docs/utility-first
#    ✔ Saved → docs_dataset/tailwind-css/utility-first.txt
#  → Fetching https://tailwindcss.com/docs/responsive-design
#    ✔ Saved → docs_dataset/tailwind-css/responsive-design.txt
#  → Fetching https://tailwindcss.com/docs/hover-focus-and-other-states
#    ✔ Saved → docs_dataset/tailwind-css/hover-focus-and-other-states.txt
#  → Fetching https://tailwindcss.com/docs/dark-mode
#    ✔ Saved → docs_dataset/tailwind-css/dark-mode.txt
#  → Fetching https://tailwindcss.com/docs/adding-custom-styles
#    ✔ Saved → docs_dataset/tailwind-css/adding-custom-styles.txt
#  → Fetching https://tailwindcss.com/docs/installation
#    ✔ Saved → docs_dataset/tailwind-css/installation.txt
#
# 📘 Processing framework: Prisma ORM
#  → Fetching https://www.prisma.io/docs/getting-started/quickstart
#    ✔ Saved → docs_dataset/prisma-orm/quickstart.txt
#  → Fetching https://www.prisma.io/docs/concepts/components/prisma-schema
#    ✔ Saved → docs_dataset/prisma-orm/prisma-schema.txt
#  → Fetching https://www.prisma.io/docs/concepts/components/prisma-client
#    ✔ Saved → docs_dataset/prisma-orm/prisma-client.txt
#  → Fetching https://www.prisma.io/docs/concepts/components/prisma-client/crud
#    ✔ Saved → docs_dataset/prisma-orm/crud.txt
#  → Fetching https://www.prisma.io/docs/concepts/components/prisma-client/relation-queries
#    ✔ Saved → docs_dataset/prisma-orm/relation-queries.txt
#  → Fetching https://www.prisma.io/docs/guides/performance-and-optimization
#    ✔ Saved → docs_dataset/prisma-orm/performance-and-optimization.txt
#
# 📘 Processing framework: Redis
#  → Fetching https://redis.io/docs/getting-started/
#    ✔ Saved → docs_dataset/redis/getting-started.txt
#  → Fetching https://redis.io/docs/data-types/strings/
#    ✔ Saved → docs_dataset/redis/strings.txt
#  → Fetching https://redis.io/docs/data-types/lists/
#    ✔ Saved → docs_dataset/redis/lists.txt
#  → Fetching https://redis.io/docs/data-types/sets/
#    ✔ Saved → docs_dataset/redis/sets.txt
#  → Fetching https://redis.io/docs/data-types/hashes/
#    ✔ Saved → docs_dataset/redis/hashes.txt
#  → Fetching https://redis.io/docs/manual/patterns/
#    ✔ Saved → docs_dataset/redis/patterns.txt
